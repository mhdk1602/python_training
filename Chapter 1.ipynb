# %% [markdown]
# ## Data Structures
#
# ##### While this might sound familiar to many to point where you would scoff and say to yourself that you can skip this as you are well versed with it, I'd kindly advice to dismiss the notion and pay attention to this module.

# %% [markdown]
# ### Different types of data structures in Python.
#
# 1. Lists
# 2. Dictionaries
# 3. Tuples
# 4. Sequences
# 5. Sets
# 6. Comprehensive Lists
#
# https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# #### EXERCISE
# ##### Consider the below list
#
# x = ["Python", "Swift", "C++", "Java", "Rust", "Julia"]
#
# 1. Execute all list functions listed in the link above and print results.
# Add following languages to the list in addition - "Golang", "React", "TypeScript"
#
#   Iterate all elements in the new list and print each element in new line.
#
#
# 2. Extract the string "Python" from the list and create a new list, then slice the list into each alphabet and print the first and last element of the list ('P' and 'n')
#
# 3. Create a new list with numbers from 0-8. Append this list to list x using zip function and print result.
#
#   [('Python', 0), ('Swift', 1), ('C++', 2), ('Java', 3), ('Rust', 4), ('Julia', 5), ('Golang', 6), ('React', 7), ('TypeScript', 8)]
#
#
# 4. Show code to check if "Java" is in new list x_new.
#
#
#
# #### Copying lists
#
# #### Deep copy vs Shallow copy
#
# ###### Deep Copy - Enables you to create a physicalized copy of the list that prevents any list operations carried on the copied list to affect the original list.
#
# Ex-
#
# x = ['chuck', 'lee', 'sonny']
#
# y = x
#
# y.remove('sonny')
#
# print(x) #=> ['chuck', 'lee', sonny]
#
# print(y) #=> ['chuck', 'lee']
#
#
# ###### Shallow copy - Creates a referenced copy that affects all changes to the original list
#
# Ex-
#
# x = ['chuck', 'lee', 'sonny']
#
# y = x
#
# y.remove('sonny')
#
# print(x) #=> ['chuck', 'lee']
#
# print(y) #=> ['chuck', 'lee']
#
#
# #### Dictionaries
#
#
# 5. Create a dictionary from above list using the dict() function.
#
#
#
# 6. Print the key value pair of the resultant dictionary using dict.items().
#
# Python 0
#
# Swift 1
#
# C++ 2
#
# Java 3
#
# Rust 4
#
# Julia 5
#
# Golang 6
#
# React 7
#
# TypeScript 8

# %% [markdown]
# #### Visulazing data structures and being familiar with the different types helps to be proficient in data parsing, cleansing and manipulation for data analysis.
#
# #### Identifying the right data structure makes this exercise meaninful and feasible.
#
# #### Iterating or looping through the data structures will be a good segue into learning looping algorithms which we will cover in detail in the following sessions.
