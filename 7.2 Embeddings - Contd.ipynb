# %%
# %pip install pymongo
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting pymongo
#   Downloading pymongo-4.6.2-cp39-cp39-macosx_10_9_universal2.whl.metadata (22 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/homebrew/lib/python3.9/site-packages (from pymongo) (2.3.0)
# Downloading pymongo-4.6.2-cp39-cp39-macosx_10_9_universal2.whl (534 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 534.6/534.6 kB 10.6 MB/s eta 0:00:0000:01
# Installing collected packages: pymongo
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed pymongo-4.6.2
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Embeddings in Data Engineering: A Comprehensive Guide
#
# In this section, we will explore various data storage solutions that are apt for handling the rich data generated from embeddings. As embeddings are high-dimensional vectors, choosing the right storage solution is vital to ensure efficient retrieval and analysis. Let's delve into the following aspects:
#
# ## Embedding Storage: Relational Databases vs. NoSQL Databases
#
# When dealing with embeddings, the choice of data storage solution is critical. Here, we compare how relational databases and NoSQL databases fare in terms of storing and managing embeddings:
#
# | Aspect                       | Relational Databases (SQL)                                                                 | NoSQL Databases                                               |
# |------------------------------|--------------------------------------------------------------------------------------------|---------------------------------------------------------------|
# | **Schema Design**            | Embeddings, being high-dimensional vectors, would require a schema with a column for each dimension, making the schema quite extensive. | Can store unstructured data such as embeddings as arrays or lists, allowing for a more compact and natural storage structure. |
# | **Data Retrieval**           | Can retrieve embeddings using SQL queries, but complex queries for finding similar embeddings might be less efficient. | Can be optimized to retrieve similar embeddings quickly and efficiently, which is a common operation when working with embeddings. |
# | **Storage Efficiency**       | Storing high-dimensional vectors in a structured format may not be space-efficient, potentially increasing storage costs. | Can handle a large volume of data (like embeddings) efficiently, offering a scalable solution for large datasets. |
# | **Suitability for Embeddings** | May face challenges in efficiently storing and retrieving high-dimensional embeddings. | More suited for storing embeddings due to flexible data models and scalability. |
#
# In the next sections, we will delve deeper into each of these aspects with Python examples demonstrating how to store and retrieve embeddings in both SQL and NoSQL databases, highlighting the performance and efficiency considerations for each.

# %% [markdown]
# ### Storing and Retrieving Embeddings in SQL Databases

# %%
import sqlite3
import numpy as np

# Create a new SQLite database (or connect to an existing database)
conn = sqlite3.connect('embeddings.db')
cursor = conn.cursor()

# Create a new table to store embeddings (assuming 3-dimensional embeddings for simplicity)
cursor.execute('''
CREATE TABLE embeddings (
    id INTEGER PRIMARY KEY,
    dimension1 REAL,
    dimension2 REAL,
    dimension3 REAL
)
''')

# Insert an embedding vector into the database
embedding_vector = np.array([0.1, 0.2, 0.3])
cursor.execute('''
INSERT INTO embeddings (dimension1, dimension2, dimension3)
VALUES (?, ?, ?)
''', tuple(embedding_vector))

# Commit the transaction
conn.commit()

# Retrieve the embedding vector from the database
cursor.execute('SELECT * FROM embeddings WHERE id = 1')
retrieved_vector = cursor.fetchone()[1:]

# Close the connection
conn.close()

# Print the retrieved vector
print(retrieved_vector)
# Output: (0.1, 0.2, 0.3)
# Out:
# (0.1, 0.2, 0.3)

# %% [markdown]
# In this script, we are utilizing the SQLite database, a type of relational database, to store and retrieve embedding vectors. Here is a step-by-step explanation of the script and what the output indicates:
#
# 1. **Importing Necessary Libraries**:
#    ```python
#    import sqlite3
#    import numpy as np
#    ```
#    We start by importing the `sqlite3` library, which allows us to work with SQLite databases in Python, and the `numpy` library to handle arrays efficiently.
#
# 2. **Creating a New SQLite Database and Initializing a Cursor**:
#    ```python
#    # Create a new SQLite database (or connect to an existing database)
#    conn = sqlite3.connect('embeddings.db')
#    cursor = conn.cursor()
#    ```
#    We create a new SQLite database named 'embeddings.db' (or connect to it if it already exists) and initialize a cursor object to interact with the database.
#
# 3. **Creating a New Table to Store Embeddings**:
#    ```python
#    # Create a new table to store embeddings (assuming 3-dimensional embeddings for simplicity)
#    cursor.execute('''
#    CREATE TABLE embeddings (
#        id INTEGER PRIMARY KEY,
#        dimension1 REAL,
#        dimension2 REAL,
#        dimension3 REAL
#    )
#    ''')
#    ```
#    We create a new table named 'embeddings' with columns to store each dimension of the embedding vectors. In this example, we assume 3-dimensional embeddings for simplicity.
#
# 4. **Inserting an Embedding Vector into the Database**:
#    ```python
#    # Insert an embedding vector into the database
#    embedding_vector = np.array([0.1, 0.2, 0.3])
#    cursor.execute('''
#    INSERT INTO embeddings (dimension1, dimension2, dimension3)
#    VALUES (?, ?, ?)
#    ''', tuple(embedding_vector))
#    ```
#    We create a numpy array to represent a 3-dimensional embedding vector and insert it into the 'embeddings' table in the database.
#
# 5. **Committing the Transaction and Retrieving the Embedding Vector**:
#    ```python
#    # Commit the transaction
#    conn.commit()
#
#    # Retrieve the embedding vector from the database
#    cursor.execute('SELECT * FROM embeddings WHERE id = 1')
#    retrieved_vector = cursor.fetchone()[1:]
#    ```
#    We commit the transaction to save the changes to the database, and then retrieve the embedding vector we inserted using a SQL SELECT query.
#
# 6. **Closing the Connection and Printing the Retrieved Vector**:
#    ```python
#    # Close the connection
#    conn.close()
#
#    # Print the retrieved vector
#    print(retrieved_vector)
#    # Output: (0.1, 0.2, 0.3)
#    ```
#    Finally, we close the connection to the database and print the retrieved vector to verify that it matches the vector we inserted.
#
# **Understanding the Output**:
# - The output, `(0.1, 0.2, 0.3)`, confirms that we successfully stored and retrieved the embedding vector from the SQLite database. It indicates that the database operations of inserting and retrieving data were performed correctly, showcasing how a relational database can be used to handle embedding data, albeit with the limitation of handling only low-dimensional embeddings efficiently.

# %% [markdown]
# ### Storing and Retrieving Embeddings in NoSQL Databases

# %%
from pymongo import MongoClient
import numpy as np

# Connect to the MongoDB server
client = MongoClient('mongodb://localhost:27017/')

# Create a new database and a new collection
db = client['embedding_database']
collection = db['embedding_collection']

# Insert an embedding vector into the database (assuming 3-dimensional embeddings for simplicity)
embedding_vector = np.array([0.1, 0.2, 0.3]).tolist()
collection.insert_one({'embedding_vector': embedding_vector})

# Retrieve the embedding vector from the database
retrieved_document = collection.find_one()
retrieved_vector = retrieved_document['embedding_vector']

# Close the connection
client.close()

# Print the retrieved vector
print(retrieved_vector)
# Output: [0.1, 0.2, 0.3]
# Out:
# [0.1, 0.2, 0.3]

# %% [markdown]
# In this script, we are utilizing MongoDB, a popular NoSQL database, to store and retrieve embedding vectors. Here is a step-by-step explanation of the script and what the output indicates:
#
# 1. **Importing Necessary Libraries**:
#    ```python
#    from pymongo import MongoClient
#    import numpy as np
#    ```
#    We start by importing the necessary libraries: `pymongo` to interact with MongoDB and `numpy` to handle arrays efficiently.
#
# 2. **Connecting to MongoDB and Creating a Database and Collection**:
#    ```python
#    # Connect to the MongoDB server
#    client = MongoClient('mongodb://localhost:27017/')
#
#    # Create a new database and a new collection
#    db = client['embedding_database']
#    collection = db['embedding_collection']
#    ```
#    We establish a connection to the MongoDB server running locally and create a new database named 'embedding_database'. Inside this database, we create a new collection called 'embedding_collection' where our embeddings will be stored.
#
# 3. **Inserting an Embedding Vector into the Database**:
#    ```python
#    # Insert an embedding vector into the database (assuming 3-dimensional embeddings for simplicity)
#    embedding_vector = np.array([0.1, 0.2, 0.3]).tolist()
#    collection.insert_one({'embedding_vector': embedding_vector})
#    ```
#    We create a numpy array representing a 3-dimensional embedding vector and convert it to a Python list, which is then inserted into the MongoDB collection as a document. The document contains a field 'embedding_vector' holding the list representation of the embedding vector.
#
# 4. **Retrieving the Embedding Vector from the Database**:
#    ```python
#    # Retrieve the embedding vector from the database
#    retrieved_document = collection.find_one()
#    retrieved_vector = retrieved_document['embedding_vector']
#    ```
#    We use the `find_one` method to retrieve the first document from the collection, which contains our stored embedding vector. We then extract the 'embedding_vector' field from the document to get the stored embedding vector.
#
# 5. **Closing the Connection and Printing the Retrieved Vector**:
#    ```python
#    # Close the connection
#    client.close()
#
#    # Print the retrieved vector
#    print(retrieved_vector)
#    # Output: [0.1, 0.2, 0.3]
#    ```
#    After retrieving the vector, we close the connection to the MongoDB server and print the retrieved vector to verify that it matches the vector we inserted.
#
# **Understanding the Output**:
# - The output, `[0.1, 0.2, 0.3]`, confirms that we successfully stored and retrieved the embedding vector from the MongoDB database. It indicates that the database operations of inserting and retrieving data were executed correctly, showcasing how a NoSQL database can be utilized to store and handle embedding data efficiently, especially given the flexible data models that NoSQL databases offer.
#
# This script demonstrates a method to store and retrieve embedding vectors in a NoSQL database using Python and MongoDB, highlighting a potential approach to managing embeddings in data engineering tasks with the flexibility and scalability that NoSQL databases provide.

# %% [markdown]
# ---
#
# ### Open-Source Distributed File Systems for Embedding Storage
#
# In this section, we delve into the functionalities of Hadoop HDFS, a scalable open-source distributed file system, and explore its potential as a solution for storing and managing large volumes of embedding data efficiently.
#
# #### Hadoop HDFS
#
# ##### Introduction to HDFS
#
# Hadoop Distributed File System (HDFS) is an integral component of the Apache Hadoop project, designed to store and manage very large files across a distributed set of machines. The system is setup in a way that data is distributed across several servers, and parallel operations can be performed on the data, which proves to be highly efficient for storing and analyzing large volumes of data, including high-dimensional embeddings. Due to its distributed nature, it is fault-tolerant, offering reliability and scalability, which are vital attributes when handling big data scenarios like storing embeddings.
#
# ##### Storing Embeddings in HDFS
#
# To store embeddings effectively in HDFS, it's essential to consider the following steps:
#
# 1. **File Format Selection**: Depending on the nature of the embeddings, selecting an appropriate file format is crucial. Common choices could be plain text formats (like CSV) for ease of use or binary formats (like Parquet) that are more space-efficient and support complex data structures.
#
# 2. **Data Serialization**: Before storing the embeddings, they need to be serialized. Serialization is the process of converting the in-memory representation of the embeddings (like arrays in Python) to a format that can be stored persistently. In Python, libraries such as `pickle` can be used for serialization.
#
# 3. **Writing Data to HDFS**: This involves using HDFS APIs or Python libraries like `pydoop` that allow interaction with HDFS to write the serialized data to the file system. The data is generally written in blocks, distributed across different nodes in the HDFS cluster.
#
# ##### Retrieving Embeddings from HDFS
#
# When it comes to retrieving embeddings stored in HDFS for further analysis or processing, the following steps are generally involved:
#
# 1. **Reading Data from HDFS**: Utilize HDFS APIs or Python libraries that facilitate reading data from HDFS. The embeddings data stored in files in HDFS can be read into the local computational environment for further operations.
#
# 2. **Data Deserialization**: After reading the data, it needs to be deserialized to convert it back to its original format, facilitating further analysis or processing. This involves converting the stored format back into in-memory data structures like arrays or lists.
#
# In the following section, we will provide Python examples demonstrating the conceptual steps involved in storing and retrieving embeddings from HDFS, considering the practical complexities of setting up and interacting with an HDFS cluster.
#
#
# ### Using MinIO for Storing Embeddings
#
# In the context of data engineering, especially when working with embeddings, storing and managing large volumes of data efficiently is a common requirement. Distributed file systems offer a solution to this by providing scalable and reliable data storage solutions. MinIO is one such open-source object storage server that is compatible with Amazon S3 APIs. It provides an excellent platform to handle large data volumes, such as embeddings, due to its high performance and scalability.
#
# #### Why Use MinIO?
#
# 1. **Ease of Use**: MinIO is easy to set up and use, making it a convenient choice for developers.
# 2. **High Performance**: It is designed for high-performance object storage, making it suitable for storing large volumes of data, including embeddings.
# 3. **S3 Compatibility**: MinIO is compatible with Amazon S3 APIs, which allows for easy integration with S3 compatible tools and SDKs.
# 4. **Open-Source**: Being open-source, it provides the flexibility of customization and integration as per the project requirements.
#
# #### Setting Up MinIO Locally
#
# To set up MinIO locally, follow these steps:
#
# 1. **Install Docker**: Ensure Docker is installed on your system. If not, download it from the [Docker official website](https://www.docker.com/get-started).
#
# 2. **Pull MinIO Docker Image**: Open a terminal and run the following command to pull the MinIO Docker image:
# `docker pull minio/minio`
#
# 3. **Run MinIO Server**: Start the MinIO server using the following command:
# `docker run -p 9000:9000 minio/minio server /data`
#
# This command starts the MinIO server and maps port 9000 on your local machine to port 9000 on the Docker container, allowing you to access the MinIO server at `http://127.0.0.1:9000`.
#
# 4. **Access MinIO Console**: Once the server is running, open a web browser and go to `http://127.0.0.1:9000` to access the MinIO Console. The default access and secret keys are both `minioadmin`.
#
# With MinIO set up, we can proceed to create Python scripts to store and retrieve embeddings in MinIO, demonstrating a practical approach to managing embeddings in data engineering tasks.

# %%
# !pip install minio
# !pip install numpy
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting minio
#   Downloading minio-7.2.5-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.9/site-packages (from minio) (2021.5.30)
# Requirement already satisfied: urllib3 in /Users/malempatiharidines/Library/Python/3.9/lib/python/site-packages (from minio) (1.26.14)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/lib/python3.9/site-packages (from minio) (20.1.0)
# Collecting pycryptodome (from minio)
#   Downloading pycryptodome-3.20.0-cp35-abi3-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.9/site-packages (from minio) (4.10.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/homebrew/lib/python3.9/site-packages (from argon2-cffi->minio) (1.14.6)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.9/site-packages (from argon2-cffi->minio) (1.16.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->minio) (2.20)
# Downloading minio-7.2.5-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 4.6 MB/s eta 0:00:00
# Downloading pycryptodome-3.20.0-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pycryptodome, minio
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed minio-7.2.5 pycryptodome-3.20.0
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: numpy in /Users/malempatiharidines/Library/Python/3.9/lib/python/site-packages (1.24.2)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-info">To illustrate the effective storage and retrieval of a large set of embeddings using a distributed file system. The primary objective is to create a substantial dataset of embeddings, derived from a rich source of information - PDF files, particularly books. Here, we elucidate the rationale behind our approach and the choice of the BERT model for generating embeddings.</div>
#
# #### Creating a Large Set of Embeddings from PDFs
#
# 1. **Objective of Creating a Large Dataset**:
#    The foremost goal is to create a large dataset of embeddings that can effectively demonstrate the capabilities of distributed file systems in handling substantial volumes of complex data, thereby showcasing efficient storage and retrieval mechanisms.
#
# 2. **Utilizing PDFs as a Data Source**:
#    PDF files, specifically books, encapsulate a vast repository of knowledge and information on varied subjects. By creating embeddings from the text data in these files, we can construct a meaningful and extensive dataset that serves as a significant asset for various data science applications.
#
# 3. **Significance of Embeddings**:
#    Embeddings play a pivotal role in converting raw text data into a format conducive to analysis and processing. These high-dimensional vectors encapsulate semantic relationships between words and phrases, serving as a fundamental building block in data science and machine learning applications.
#
# 4. **Applications in Search and Recommendation Systems**:
#    Embeddings also find substantial applications in building intelligent search and recommendation systems. These systems can process natural language queries, provide relevant search results, and offer personalized recommendations, thereby enhancing the user experience.
#
# #### Choice of BERT Model Over spaCy
#
# 1. **Contextual Embeddings**: BERT (Bidirectional Encoder Representations from Transformers) is known for creating contextual embeddings. It considers the context of words during embedding generation, capturing more nuanced meanings and semantic relationships compared to traditional embedding methods.
#
# 2. **Handling Broader Context**: Given that we are dealing with books, which contain long and detailed narratives or discussions, BERT is capable of handling broader contexts more effectively compared to spaCy, which might lose some contextual information when the text is chunked into smaller pieces.
#
# 3. **Segment-Level Embeddings**: BERT allows for the creation of segment-level embeddings (like paragraphs or sections), preserving more of the document structure and contextual information compared to sentence-level embeddings that might be created using spaCy.
#
# 4. **State-of-the-Art Performance**: BERT has delivered state-of-the-art performance on a wide range of NLP tasks, making it a reliable choice for creating high-quality embeddings that can capture complex relationships in the text data extracted from PDFs.
#
# By choosing BERT for this task, we aim to create embeddings that can effectively capture the rich and complex information contained in books, paving the way for more advanced analysis and applications in data science and machine learning.
#
#
# In the ensuing sections, we will detail the process of using the BERT model to create embeddings from the text data extracted from PDFs. Subsequently, we will illustrate how to efficiently store and manage these embeddings using MinIO, a high-performance distributed file system.

# %%
import os
import fitz  # PyMuPDF
from transformers import BertModel, BertTokenizer
import torch
from minio import Minio
import pickle
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import sent_tokenize

# Step 1: Extract text from PDF files and tokenize into sentences
directory = 'gitignore-files'
pdf_text_data = {}

for filename in tqdm(os.listdir(directory), desc="Reading PDFs", unit="file"):
    if filename.endswith(".pdf"):
        file_path = os.path.join(directory, filename)
        
        # Open the PDF file
        doc = fitz.open(file_path)
        text = ""
        
        # Combine text from all pages into a single string
        for page in doc:
            text += page.get_text()
        pdf_text_data[filename] = sent_tokenize(text)  # Tokenize text into sentences

# Step 2: Load the pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Step 3: Create sentence-level embeddings for the text from each PDF file
embeddings_data = {}
for filename, sentences in tqdm(pdf_text_data.items(), desc="Creating Embeddings - Files", unit="file"):
    embeddings_data[filename] = []
    for sentence in tqdm(sentences, desc="Creating Embeddings - Sentences", unit="sentence"):
        # Skip empty sentences
        if not sentence.strip():
            continue
        
        # Tokenize the sentence and create an embedding
        inputs = tokenizer(sentence, return_tensors='pt', max_length=512, truncation=True)
        with torch.no_grad():
            outputs = model(**inputs)
        embeddings_data[filename].append(outputs.last_hidden_state.mean(dim=1).numpy())

# Step 4: Setup MinIO client and create a bucket
client = Minio(
    "127.0.0.1:9000",
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False
)
bucket_name = "embeddings-new"
client.make_bucket(bucket_name)

# Step 5: Serialize and store embeddings in MinIO
for filename, embedding_list in tqdm(embeddings_data.items(), desc="Uploading embeddings", unit="file"):
    for i, embedding in enumerate(embedding_list):
        # Create a unique object name based on the file name and sentence index
        object_name = f"{filename.replace('.pdf', '')}_sentence_{i}_embedding.pkl"
        
        # Serialize the embedding data
        serialized_embedding = pickle.dumps(embedding)
        
        # Upload the serialized data to MinIO
        client.put_object(bucket_name, object_name, io.BytesIO(serialized_embedding), len(serialized_embedding))

# Step 6: Query the embeddings in a loop until the user decides to quit
while True:
    user_question = input("Please enter context search (or type 'quit' to exit): ")
    
    if user_question.lower() == 'quit':
        break

    # Create an embedding for the query
    query_inputs = tokenizer(user_question, return_tensors='pt')
    with torch.no_grad():
        query_outputs = model(**query_inputs)
    query_embedding = query_outputs.last_hidden_state.mean(dim=1).numpy()

    # Retrieve embeddings from MinIO, find the most similar sentences, and display them
    similar_sentences = []

    for obj in tqdm(client.list_objects(bucket_name), desc="Retrieving and comparing embeddings", unit="file"):
        
        # Get the object data from MinIO and deserialize to get the original embedding
        data = client.get_object(bucket_name, obj.object_name)
        retrieved_embedding = pickle.loads(data.read())
        
        # Calculate the cosine similarity between the query embedding and the retrieved embedding
        similarity = cosine_similarity(query_embedding.reshape(1, -1), retrieved_embedding.reshape(1, -1))
        
        # Get the file name and sentence index from the object name
        file_name, sentence_index = obj.object_name.replace('_embedding.pkl', '').rsplit('_sentence_', 1)
        sentence_index = int(sentence_index)
        
        # Get the text of the sentence
        sentence_text = pdf_text_data[file_name + '.pdf'][sentence_index]
        
        # Store the sentence text and similarity score
        similar_sentences.append((file_name, sentence_index, sentence_text, similarity[0][0]))

    # Find the most similar sentence and display it along with two neighboring sentences
    most_similar_sentence = max(similar_sentences, key=lambda x: x[3])
    file_name, sentence_index, sentence_text, score = most_similar_sentence
    
    # Get the neighboring sentences
    sentences = pdf_text_data[file_name + '.pdf']
    previous_sentence = sentences[max(0, sentence_index - 1)] if sentence_index > 0 else ""
    next_sentence = sentences[min(len(sentences) - 1, sentence_index + 1)] if sentence_index < len(sentences) - 1 else ""

    print(f"The most similar sentence to the query '{user_question}' is in file: {file_name}.pdf, with a similarity score of {score}")
    print(f"Context:")
    print(f"  {previous_sentence}")
    print(f"  {sentence_text}")
    print(f"  {next_sentence}")
# Out:
# Reading PDFs: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.45file/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Creating Embeddings - Files:   0%|                                                                                                                                                                                            | 0/2 [00:00<?, ?file/s]
# Creating Embeddings - Sentences:   0%|                                                                                                                                                                                 | 0/4886 [00:00<?, ?sentence/s]
# Creating Embeddings - Sentences:   0%|                                                                                                                                                                         | 3/4886 [00:00<03:43, 21.81sentence/s]
# Creating Embeddings - Sentences:   0%|▏                                                                                                                                                                        | 6/4886 [00:00<03:35, 22.65sentence/s]
# Creating Embeddings - Sentences:   0%|▎                                                                                                                                                                        | 9/4886 [00:00<03:15, 24.92sentence/s]
# Creating Embeddings - Sentences:   0%|▍                                                                                                                                                                       | 12/4886 [00:00<03:10, 25.62sentence/s]
# Creating Embeddings - Sentences:   0%|▌                                                                                                                                                                       | 15/4886 [00:00<03:07, 25.98sentence/s]
# Creating Embeddings - Sentences:   0%|▌                                                                                                                                                                       | 18/4886 [00:00<03:17, 24.69sentence/s]
# Creating Embeddings - Sentences:   0%|▋                                                                                                                                                                       | 21/4886 [00:00<03:08, 25.82sentence/s]
# Creating Embeddings - Sentences:   0%|▊                                                                                                                                                                       | 24/4886 [00:00<03:02, 26.65sentence/s]
# Creating Embeddings - Sentences:   1%|▉                                                                                                                                                                       | 27/4886 [00:01<02:57, 27.40sentence/s]
# Creating Embeddings - Sentences:   1%|█                                                                                                                                                                       | 30/4886 [00:01<02:58, 27.27sentence/s]
# Creating Embeddings - Sentences:   1%|█▏                                                                                                                                                                      | 33/4886 [00:01<02:55, 27.70sentence/s]
# Creating Embeddings - Sentences:   1%|█▏                                                                                                                                                                      | 36/4886 [00:01<02:51, 28.28sentence/s]
# Creating Embeddings - Sentences:   1%|█▎                                                                                                                                                                      | 39/4886 [00:01<02:54, 27.72sentence/s]
# Creating Embeddings - Sentences:   1%|█▍                                                                                                                                                                      | 42/4886 [00:01<03:01, 26.65sentence/s]
# Creating Embeddings - Sentences:   1%|█▌                                                                                                                                                                      | 45/4886 [00:01<02:58, 27.07sentence/s]
# Creating Embeddings - Sentences:   1%|█▋                                                                                                                                                                      | 48/4886 [00:01<02:58, 27.16sentence/s]
# Creating Embeddings - Sentences:   1%|█▊                                                                                                                                                                      | 52/4886 [00:01<02:50, 28.33sentence/s]
# Creating Embeddings - Sentences:   1%|█▉                                                                                                                                                                      | 55/4886 [00:02<02:52, 28.00sentence/s]
# Creating Embeddings - Sentences:   1%|█▉                                                                                                                                                                      | 58/4886 [00:02<02:58, 27.08sentence/s]
# Creating Embeddings - Sentences:   1%|██                                                                                                                                                                      | 61/4886 [00:02<03:03, 26.35sentence/s]
# Creating Embeddings - Sentences:   1%|██▏                                                                                                                                                                     | 65/4886 [00:02<02:54, 27.59sentence/s]
# Creating Embeddings - Sentences:   1%|██▎                                                                                                                                                                     | 69/4886 [00:02<02:48, 28.58sentence/s]
# Creating Embeddings - Sentences:   1%|██▌                                                                                                                                                                     | 73/4886 [00:02<02:45, 29.17sentence/s]
# Creating Embeddings - Sentences:   2%|██▌                                                                                                                                                                     | 76/4886 [00:02<02:48, 28.60sentence/s]
# Creating Embeddings - Sentences:   2%|██▋                                                                                                                                                                     | 79/4886 [00:02<02:47, 28.73sentence/s]
# Creating Embeddings - Sentences:   2%|██▊                                                                                                                                                                     | 82/4886 [00:03<02:51, 28.09sentence/s]
# Creating Embeddings - Sentences:   2%|██▉                                                                                                                                                                     | 85/4886 [00:03<02:50, 28.21sentence/s]
# Creating Embeddings - Sentences:   2%|███                                                                                                                                                                     | 88/4886 [00:03<02:52, 27.76sentence/s]
# Creating Embeddings - Sentences:   2%|███▏                                                                                                                                                                    | 91/4886 [00:03<02:51, 27.88sentence/s]
# Creating Embeddings - Sentences:   2%|███▏                                                                                                                                                                    | 94/4886 [00:03<02:51, 27.98sentence/s]
# Creating Embeddings - Sentences:   2%|███▎                                                                                                                                                                    | 97/4886 [00:03<02:56, 27.20sentence/s]
# Creating Embeddings - Sentences:   2%|███▍                                                                                                                                                                   | 100/4886 [00:03<02:59, 26.69sentence/s]
# Creating Embeddings - Sentences:   2%|███▌                                                                                                                                                                   | 103/4886 [00:03<02:58, 26.75sentence/s]
# Creating Embeddings - Sentences:   2%|███▌                                                                                                                                                                   | 106/4886 [00:03<03:04, 25.93sentence/s]
# Creating Embeddings - Sentences:   2%|███▋                                                                                                                                                                   | 109/4886 [00:04<03:03, 25.98sentence/s]
# Creating Embeddings - Sentences:   2%|███▊                                                                                                                                                                   | 112/4886 [00:04<02:58, 26.74sentence/s]
# Creating Embeddings - Sentences:   2%|███▉                                                                                                                                                                   | 115/4886 [00:04<02:54, 27.30sentence/s]
# Creating Embeddings - Sentences:   2%|████                                                                                                                                                                   | 118/4886 [00:04<02:50, 27.90sentence/s]
# Creating Embeddings - Sentences:   2%|████▏                                                                                                                                                                  | 121/4886 [00:04<02:50, 28.01sentence/s]
# Creating Embeddings - Sentences:   3%|████▎                                                                                                                                                                  | 125/4886 [00:04<02:42, 29.38sentence/s]
# Creating Embeddings - Sentences:   3%|████▎                                                                                                                                                                  | 128/4886 [00:04<02:44, 28.92sentence/s]
# Creating Embeddings - Sentences:   3%|████▍                                                                                                                                                                  | 131/4886 [00:04<02:45, 28.76sentence/s]
# Creating Embeddings - Sentences:   3%|████▌                                                                                                                                                                  | 135/4886 [00:04<02:41, 29.45sentence/s]
# Creating Embeddings - Sentences:   3%|████▊                                                                                                                                                                  | 139/4886 [00:05<02:40, 29.57sentence/s]
# Creating Embeddings - Sentences:   3%|████▊                                                                                                                                                                  | 142/4886 [00:05<02:42, 29.19sentence/s]
# Creating Embeddings - Sentences:   3%|████▉                                                                                                                                                                  | 145/4886 [00:05<02:43, 29.08sentence/s]
# Creating Embeddings - Sentences:   3%|█████                                                                                                                                                                  | 148/4886 [00:05<02:45, 28.70sentence/s]
# Creating Embeddings - Sentences:   3%|█████▏                                                                                                                                                                 | 151/4886 [00:05<02:50, 27.85sentence/s]
# Creating Embeddings - Sentences:   3%|█████▎                                                                                                                                                                 | 154/4886 [00:05<02:49, 27.98sentence/s]
# Creating Embeddings - Sentences:   3%|█████▎                                                                                                                                                                 | 157/4886 [00:05<02:55, 26.96sentence/s]
# Creating Embeddings - Sentences:   3%|█████▍                                                                                                                                                                 | 160/4886 [00:05<02:50, 27.74sentence/s]
# Creating Embeddings - Sentences:   3%|█████▌                                                                                                                                                                 | 163/4886 [00:05<02:46, 28.29sentence/s]
# Creating Embeddings - Sentences:   3%|█████▋                                                                                                                                                                 | 166/4886 [00:06<02:44, 28.69sentence/s]
# Creating Embeddings - Sentences:   3%|█████▊                                                                                                                                                                 | 169/4886 [00:06<02:44, 28.69sentence/s]
# Creating Embeddings - Sentences:   4%|█████▉                                                                                                                                                                 | 172/4886 [00:06<02:48, 27.98sentence/s]
# Creating Embeddings - Sentences:   4%|█████▉                                                                                                                                                                 | 175/4886 [00:06<02:51, 27.48sentence/s]
# Creating Embeddings - Sentences:   4%|██████                                                                                                                                                                 | 178/4886 [00:06<02:49, 27.70sentence/s]
# Creating Embeddings - Sentences:   4%|██████▏                                                                                                                                                                | 181/4886 [00:06<02:49, 27.71sentence/s]
# Creating Embeddings - Sentences:   4%|██████▎                                                                                                                                                                | 184/4886 [00:06<02:46, 28.25sentence/s]
# Creating Embeddings - Sentences:   4%|██████▍                                                                                                                                                                | 187/4886 [00:06<02:46, 28.24sentence/s]
# Creating Embeddings - Sentences:   4%|██████▍                                                                                                                                                                | 190/4886 [00:06<02:51, 27.42sentence/s]
# Creating Embeddings - Sentences:   4%|██████▌                                                                                                                                                                | 193/4886 [00:06<02:52, 27.24sentence/s]
# Creating Embeddings - Sentences:   4%|██████▋                                                                                                                                                                | 196/4886 [00:07<02:52, 27.25sentence/s]
# Creating Embeddings - Sentences:   4%|██████▊                                                                                                                                                                | 199/4886 [00:07<02:50, 27.48sentence/s]
# Creating Embeddings - Sentences:   4%|██████▉                                                                                                                                                                | 202/4886 [00:07<02:52, 27.09sentence/s]
# Creating Embeddings - Sentences:   4%|███████                                                                                                                                                                | 205/4886 [00:07<02:48, 27.71sentence/s]
# Creating Embeddings - Sentences:   4%|███████                                                                                                                                                                | 208/4886 [00:07<02:51, 27.26sentence/s]
# Creating Embeddings - Sentences:   4%|███████▏                                                                                                                                                               | 211/4886 [00:07<02:50, 27.49sentence/s]
# Creating Embeddings - Sentences:   4%|███████▎                                                                                                                                                               | 214/4886 [00:07<03:05, 25.25sentence/s]
# Creating Embeddings - Sentences:   4%|███████▍                                                                                                                                                               | 217/4886 [00:07<03:12, 24.22sentence/s]
# Creating Embeddings - Sentences:   5%|███████▌                                                                                                                                                               | 220/4886 [00:08<03:04, 25.22sentence/s]
# Creating Embeddings - Sentences:   5%|███████▌                                                                                                                                                               | 223/4886 [00:08<03:00, 25.77sentence/s]
# Creating Embeddings - Sentences:   5%|███████▋                                                                                                                                                               | 226/4886 [00:08<03:00, 25.88sentence/s]
# Creating Embeddings - Sentences:   5%|███████▊                                                                                                                                                               | 230/4886 [00:08<02:49, 27.43sentence/s]
# Creating Embeddings - Sentences:   5%|███████▉                                                                                                                                                               | 233/4886 [00:08<02:45, 28.07sentence/s]
# Creating Embeddings - Sentences:   5%|████████                                                                                                                                                               | 236/4886 [00:08<02:47, 27.84sentence/s]
# Creating Embeddings - Sentences:   5%|████████▏                                                                                                                                                              | 240/4886 [00:08<02:41, 28.82sentence/s]
# Creating Embeddings - Sentences:   5%|████████▎                                                                                                                                                              | 243/4886 [00:08<02:40, 28.99sentence/s]
# Creating Embeddings - Sentences:   5%|████████▍                                                                                                                                                              | 246/4886 [00:08<02:41, 28.76sentence/s]
# Creating Embeddings - Sentences:   5%|████████▌                                                                                                                                                              | 249/4886 [00:09<02:41, 28.76sentence/s]
# Creating Embeddings - Sentences:   5%|████████▌                                                                                                                                                              | 252/4886 [00:09<02:47, 27.66sentence/s]
# Creating Embeddings - Sentences:   5%|████████▋                                                                                                                                                              | 256/4886 [00:09<02:42, 28.55sentence/s]
# Creating Embeddings - Sentences:   5%|████████▊                                                                                                                                                              | 259/4886 [00:09<02:46, 27.73sentence/s]
# Creating Embeddings - Sentences:   5%|████████▉                                                                                                                                                              | 262/4886 [00:09<02:46, 27.78sentence/s]
# Creating Embeddings - Sentences:   5%|█████████                                                                                                                                                              | 265/4886 [00:09<02:44, 28.01sentence/s]
# Creating Embeddings - Sentences:   5%|█████████▏                                                                                                                                                             | 268/4886 [00:09<02:43, 28.17sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▎                                                                                                                                                             | 271/4886 [00:09<02:52, 26.81sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▎                                                                                                                                                             | 274/4886 [00:09<02:51, 26.86sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▍                                                                                                                                                             | 277/4886 [00:10<02:49, 27.15sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▌                                                                                                                                                             | 280/4886 [00:10<02:49, 27.19sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▋                                                                                                                                                             | 283/4886 [00:10<02:48, 27.34sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▊                                                                                                                                                             | 286/4886 [00:10<02:48, 27.37sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▉                                                                                                                                                             | 289/4886 [00:10<02:44, 27.89sentence/s]
# Creating Embeddings - Sentences:   6%|█████████▉                                                                                                                                                             | 292/4886 [00:10<02:46, 27.65sentence/s]
# Creating Embeddings - Sentences:   6%|██████████                                                                                                                                                             | 295/4886 [00:10<02:42, 28.18sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▏                                                                                                                                                            | 298/4886 [00:10<02:41, 28.44sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▎                                                                                                                                                            | 302/4886 [00:10<02:37, 29.10sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▍                                                                                                                                                            | 305/4886 [00:11<02:36, 29.34sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▌                                                                                                                                                            | 308/4886 [00:11<02:35, 29.42sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▋                                                                                                                                                            | 311/4886 [00:11<02:35, 29.49sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▋                                                                                                                                                            | 314/4886 [00:11<02:36, 29.20sentence/s]
# Creating Embeddings - Sentences:   6%|██████████▊                                                                                                                                                            | 317/4886 [00:11<02:36, 29.11sentence/s]
# Creating Embeddings - Sentences:   7%|██████████▉                                                                                                                                                            | 320/4886 [00:11<02:40, 28.53sentence/s]
# Creating Embeddings - Sentences:   7%|███████████                                                                                                                                                            | 323/4886 [00:11<02:41, 28.31sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▏                                                                                                                                                           | 326/4886 [00:11<02:42, 28.05sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▏                                                                                                                                                           | 329/4886 [00:11<02:48, 27.06sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▎                                                                                                                                                           | 332/4886 [00:12<02:45, 27.48sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▍                                                                                                                                                           | 335/4886 [00:12<02:42, 27.99sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▌                                                                                                                                                           | 338/4886 [00:12<02:49, 26.91sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▋                                                                                                                                                           | 341/4886 [00:12<02:59, 25.30sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▊                                                                                                                                                           | 344/4886 [00:12<02:54, 26.01sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▊                                                                                                                                                           | 347/4886 [00:12<03:00, 25.20sentence/s]
# Creating Embeddings - Sentences:   7%|███████████▉                                                                                                                                                           | 350/4886 [00:12<03:04, 24.59sentence/s]
# Creating Embeddings - Sentences:   7%|████████████                                                                                                                                                           | 353/4886 [00:12<02:57, 25.57sentence/s]
# Creating Embeddings - Sentences:   7%|████████████▏                                                                                                                                                          | 356/4886 [00:12<02:51, 26.35sentence/s]
# Creating Embeddings - Sentences:   7%|████████████▎                                                                                                                                                          | 360/4886 [00:13<02:42, 27.88sentence/s]
# Creating Embeddings - Sentences:   7%|████████████▍                                                                                                                                                          | 363/4886 [00:13<02:41, 27.94sentence/s]
# Creating Embeddings - Sentences:   7%|████████████▌                                                                                                                                                          | 366/4886 [00:13<02:40, 28.22sentence/s]
# Creating Embeddings - Sentences:   8%|████████████▌                                                                                                                                                          | 369/4886 [00:13<02:41, 28.02sentence/s]
# Creating Embeddings - Sentences:   8%|████████████▋                                                                                                                                                          | 372/4886 [00:13<02:40, 28.13sentence/s]
# Creating Embeddings - Sentences:   8%|████████████▊                                                                                                                                                          | 375/4886 [00:13<02:39, 28.22sentence/s]
# Creating Embeddings - Sentences:   8%|████████████▉                                                                                                                                                          | 378/4886 [00:13<02:40, 28.10sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████                                                                                                                                                          | 381/4886 [00:13<02:43, 27.51sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████                                                                                                                                                          | 384/4886 [00:13<02:46, 27.00sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▏                                                                                                                                                         | 387/4886 [00:14<02:56, 25.50sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▎                                                                                                                                                         | 391/4886 [00:14<02:47, 26.84sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▍                                                                                                                                                         | 394/4886 [00:14<02:57, 25.35sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▌                                                                                                                                                         | 398/4886 [00:14<02:46, 27.03sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▋                                                                                                                                                         | 402/4886 [00:14<02:40, 27.87sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▊                                                                                                                                                         | 405/4886 [00:14<02:38, 28.35sentence/s]
# Creating Embeddings - Sentences:   8%|█████████████▉                                                                                                                                                         | 408/4886 [00:14<02:41, 27.67sentence/s]
# Creating Embeddings - Sentences:   8%|██████████████                                                                                                                                                         | 411/4886 [00:14<02:38, 28.15sentence/s]
# Creating Embeddings - Sentences:   8%|██████████████▏                                                                                                                                                        | 415/4886 [00:15<02:36, 28.56sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▎                                                                                                                                                        | 419/4886 [00:15<02:31, 29.43sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▍                                                                                                                                                        | 422/4886 [00:15<02:33, 29.04sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▌                                                                                                                                                        | 425/4886 [00:15<02:34, 28.93sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▋                                                                                                                                                        | 428/4886 [00:15<02:47, 26.66sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▋                                                                                                                                                        | 431/4886 [00:15<02:46, 26.69sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▊                                                                                                                                                        | 435/4886 [00:15<02:40, 27.72sentence/s]
# Creating Embeddings - Sentences:   9%|██████████████▉                                                                                                                                                        | 438/4886 [00:15<02:41, 27.61sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████                                                                                                                                                        | 441/4886 [00:16<02:47, 26.50sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▏                                                                                                                                                       | 444/4886 [00:16<02:53, 25.59sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▎                                                                                                                                                       | 447/4886 [00:16<02:55, 25.22sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▍                                                                                                                                                       | 450/4886 [00:16<02:54, 25.36sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▍                                                                                                                                                       | 453/4886 [00:16<02:50, 26.05sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▌                                                                                                                                                       | 456/4886 [00:16<02:53, 25.46sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▋                                                                                                                                                       | 459/4886 [00:16<02:54, 25.31sentence/s]
# Creating Embeddings - Sentences:   9%|███████████████▊                                                                                                                                                       | 462/4886 [00:16<02:49, 26.12sentence/s]
# Creating Embeddings - Sentences:  10%|███████████████▉                                                                                                                                                       | 465/4886 [00:16<02:44, 26.81sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████                                                                                                                                                       | 469/4886 [00:17<02:38, 27.82sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▏                                                                                                                                                      | 472/4886 [00:17<02:35, 28.39sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▏                                                                                                                                                      | 475/4886 [00:17<02:44, 26.88sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▎                                                                                                                                                      | 478/4886 [00:17<02:50, 25.91sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▍                                                                                                                                                      | 482/4886 [00:17<02:40, 27.39sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▌                                                                                                                                                      | 485/4886 [00:17<02:45, 26.52sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▋                                                                                                                                                      | 488/4886 [00:17<02:49, 26.00sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▊                                                                                                                                                      | 491/4886 [00:17<02:43, 26.85sentence/s]
# Creating Embeddings - Sentences:  10%|████████████████▉                                                                                                                                                      | 495/4886 [00:18<02:41, 27.13sentence/s]
# Creating Embeddings - Sentences:  10%|█████████████████                                                                                                                                                      | 498/4886 [00:18<02:47, 26.25sentence/s]
# Creating Embeddings - Sentences:  10%|█████████████████                                                                                                                                                      | 501/4886 [00:18<02:42, 27.05sentence/s]
# Creating Embeddings - Sentences:  10%|█████████████████▏                                                                                                                                                     | 504/4886 [00:18<02:39, 27.54sentence/s]
# Creating Embeddings - Sentences:  10%|█████████████████▎                                                                                                                                                     | 507/4886 [00:18<02:36, 27.95sentence/s]
# Creating Embeddings - Sentences:  10%|█████████████████▍                                                                                                                                                     | 510/4886 [00:18<02:39, 27.47sentence/s]
# Creating Embeddings - Sentences:  11%|█████████████████▌                                                                                                                                                     | 514/4886 [00:18<02:35, 28.17sentence/s]
# Creating Embeddings - Sentences:  11%|█████████████████▋                                                                                                                                                     | 517/4886 [00:18<02:37, 27.68sentence/s]
# Creating Embeddings - Sentences:  11%|█████████████████▊                                                                                                                                                     | 520/4886 [00:19<02:51, 25.45sentence/s]
# Creating Embeddings - Sentences:  11%|█████████████████▉                                                                                                                                                     | 523/4886 [00:19<03:11, 22.79sentence/s]
# Creating Embeddings - Sentences:  11%|█████████████████▉                                                                                                                                                     | 526/4886 [00:19<03:09, 23.01sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████                                                                                                                                                     | 529/4886 [00:19<03:00, 24.11sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▏                                                                                                                                                    | 532/4886 [00:19<02:54, 24.98sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▎                                                                                                                                                    | 535/4886 [00:19<02:54, 24.91sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▍                                                                                                                                                    | 538/4886 [00:19<02:58, 24.35sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▍                                                                                                                                                    | 541/4886 [00:19<02:58, 24.39sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▌                                                                                                                                                    | 544/4886 [00:20<03:07, 23.14sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▋                                                                                                                                                    | 547/4886 [00:20<02:54, 24.84sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▊                                                                                                                                                    | 550/4886 [00:20<02:53, 25.03sentence/s]
# Creating Embeddings - Sentences:  11%|██████████████████▉                                                                                                                                                    | 553/4886 [00:20<02:46, 26.05sentence/s]
# Creating Embeddings - Sentences:  11%|███████████████████                                                                                                                                                    | 556/4886 [00:20<02:51, 25.18sentence/s]
# Creating Embeddings - Sentences:  11%|███████████████████                                                                                                                                                    | 559/4886 [00:20<02:51, 25.16sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▏                                                                                                                                                   | 562/4886 [00:20<02:44, 26.25sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▎                                                                                                                                                   | 566/4886 [00:20<02:35, 27.86sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▍                                                                                                                                                   | 569/4886 [00:20<02:38, 27.29sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▌                                                                                                                                                   | 572/4886 [00:21<02:46, 25.84sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▋                                                                                                                                                   | 575/4886 [00:21<02:41, 26.65sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▊                                                                                                                                                   | 579/4886 [00:21<02:34, 27.87sentence/s]
# Creating Embeddings - Sentences:  12%|███████████████████▉                                                                                                                                                   | 583/4886 [00:21<02:30, 28.61sentence/s]
# Creating Embeddings - Sentences:  12%|████████████████████                                                                                                                                                   | 586/4886 [00:21<02:29, 28.72sentence/s]
# ...
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████    | 7634/7820 [05:04<00:06, 29.65sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 7638/7820 [05:04<00:06, 30.03sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 7641/7820 [05:04<00:06, 29.25sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 7644/7820 [05:04<00:06, 29.07sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 7647/7820 [05:04<00:06, 28.27sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 7650/7820 [05:04<00:06, 25.85sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 7653/7820 [05:04<00:06, 25.99sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌   | 7656/7820 [05:04<00:06, 24.91sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌   | 7659/7820 [05:05<00:07, 22.88sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 7662/7820 [05:05<00:06, 24.32sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 7665/7820 [05:05<00:06, 25.73sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊   | 7669/7820 [05:05<00:05, 26.99sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊   | 7672/7820 [05:05<00:05, 25.92sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 7675/7820 [05:05<00:05, 26.63sentence/s]
# Creating Embeddings - Sentences:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 7678/7820 [05:05<00:05, 25.87sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████   | 7681/7820 [05:05<00:05, 26.02sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████   | 7684/7820 [05:05<00:05, 25.48sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 7687/7820 [05:06<00:05, 24.09sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 7690/7820 [05:06<00:05, 24.30sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 7693/7820 [05:06<00:04, 25.68sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 7696/7820 [05:06<00:04, 26.24sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍  | 7699/7820 [05:06<00:04, 25.80sentence/s]
# Creating Embeddings - Sentences:  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍  | 7702/7820 [05:06<00:04, 26.29sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌  | 7705/7820 [05:06<00:04, 25.35sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌  | 7708/7820 [05:06<00:04, 25.04sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 7711/7820 [05:07<00:04, 24.19sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 7714/7820 [05:07<00:04, 24.33sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊  | 7717/7820 [05:07<00:04, 24.68sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 7720/7820 [05:07<00:03, 25.46sentence/s]
# Creating Embeddings - Sentences:  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 7723/7820 [05:07<00:04, 20.75sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 7726/7820 [05:07<00:04, 22.17sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 7729/7820 [05:07<00:04, 22.39sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 7733/7820 [05:07<00:03, 24.89sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 7736/7820 [05:08<00:03, 25.66sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 7739/7820 [05:08<00:03, 25.06sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 7742/7820 [05:08<00:03, 24.67sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍ | 7746/7820 [05:08<00:02, 26.23sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 7750/7820 [05:08<00:02, 27.35sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 7753/7820 [05:08<00:02, 27.60sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 7756/7820 [05:08<00:02, 27.68sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 7760/7820 [05:08<00:02, 28.86sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊ | 7764/7820 [05:09<00:01, 29.20sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 7768/7820 [05:09<00:01, 29.70sentence/s]
# Creating Embeddings - Sentences:  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 7771/7820 [05:09<00:01, 29.03sentence/s]
# Creating Embeddings - Sentences:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 7774/7820 [05:09<00:01, 26.75sentence/s]
# Creating Embeddings - Sentences:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 7777/7820 [05:09<00:01, 26.69sentence/s]
# Creating Embeddings - Sentences:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏| 7780/7820 [05:09<00:01, 24.99sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏| 7783/7820 [05:09<00:01, 25.97sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎| 7786/7820 [05:09<00:01, 26.12sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎| 7789/7820 [05:10<00:01, 26.99sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 7792/7820 [05:10<00:01, 26.56sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 7795/7820 [05:10<00:00, 27.09sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 7798/7820 [05:10<00:00, 26.78sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 7801/7820 [05:10<00:00, 25.36sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 7804/7820 [05:10<00:00, 21.50sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 7807/7820 [05:10<00:00, 23.21sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 7810/7820 [05:10<00:00, 23.03sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 7813/7820 [05:11<00:00, 23.94sentence/s]
# Creating Embeddings - Sentences: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 7816/7820 [05:11<00:00, 24.45sentence/s]
# Creating Embeddings - Sentences: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7820/7820 [05:11<00:00, 25.12sentence/s]
# Creating Embeddings - Files: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [08:07<00:00, 243.52s/file]
# Uploading embeddings: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:38<00:00, 19.50s/file]
# Please enter context search (or type 'quit' to exit): ahab kills the whale
# Retrieving and comparing embeddings: 12706file [00:36, 350.23file/s]
# The most similar sentence to the query 'ahab kills the whale' is in file: moby-dick.pdf, with a similarity score of 0.7130804061889648
# Context:
#   
# CHAPTER XLVII.
#   AHAB’S BOAT AND CREW.
#   FEDALLAH
# ”Who would have thought it, Flask!“ cried Stubb; ”if I had but one leg you would
# not catch me in a boat, unless maybe to stop the plug-hole with my timber toe.

# %% [markdown]
# ### Embedding Storage and Retrieval with MinIO
#
# This script demonstrates how to extract text from PDF files, create sentence-level embeddings using the BERT model, store these embeddings in MinIO (a high-performance distributed object storage server), and then use these embeddings to find the most similar sentences in response to a user query. Here is a step-by-step explanation of each part of the script:
#
# #### Step 1: Extract Text from PDF Files and Tokenize into Sentences
#
# In this step, the script reads PDF files from the specified directory and extracts the text content from each file. The extracted text is then tokenized into individual sentences using the `sent_tokenize` function from the NLTK library.
#
# #### Step 2: Load the Pre-trained BERT Model and Tokenizer
#
# The script loads a pre-trained BERT model and tokenizer from the Hugging Face Transformers library. The BERT model will be used to create embeddings for the sentences extracted from the PDF files.
#
# #### Step 3: Create Sentence-Level Embeddings
#
# For each sentence extracted from the PDF files, the script creates an embedding using the BERT model. These embeddings are stored in a dictionary with file names as keys and lists of embeddings as values. The tokenizer is used to convert sentences into a format that can be fed into the BERT model, and the model generates embeddings for each token in the sentence. The `mean` function is then used to average these token embeddings to get a single embedding for the entire sentence.
#
# #### Step 4: Setup MinIO Client and Create a Bucket
#
# The script initializes a MinIO client to interact with the MinIO server and creates a bucket to store the embeddings. MinIO is a distributed object storage server that allows efficient storage and retrieval of large amounts of data.
#
# #### Step 5: Serialize and Store Embeddings in MinIO
#
# In this step, the script serializes the sentence embeddings and stores them in MinIO. Serialization is the process of converting the in-memory representation of the embeddings (numpy arrays) to a format that can be stored on disk (bytes). The `pickle` library is used for serialization. Each serialized embedding is then uploaded to MinIO as a separate object, with a unique name based on the file name and sentence index.
#
# #### Step 6: Query the Embeddings
#
# In the final step, the script enters a loop where it continually prompts the user to enter a query. The script creates an embedding for the query using the BERT model, and then retrieves all sentence embeddings from MinIO. It calculates the cosine similarity between the query embedding and each retrieved embedding to find the most similar sentences. The script then displays the most similar sentence along with its neighboring sentences to provide context. The loop continues until the user decides to quit by typing 'quit'.
#
# #### Why Pickling?
#
# Pickling is a serialization process to convert Python objects into a byte stream. This byte stream can be stored or transmitted over a network. Later on, this byte stream can be deserialized to get back the original Python objects. In our case, we are pickling the embeddings (numpy arrays) to store them in MinIO, and later unpickling them during retrieval.
#
# #### Retrieval and Displaying Context
#
# During retrieval, the script retrieves the embeddings from MinIO and calculates the cosine similarity with the query embedding to find the most similar sentence. It also retrieves two neighboring sentences to provide a broader context for the answer. This allows the user to see not only the sentence that most closely matches their query but also the surrounding text, which can provide additional information and make the answer more informative.
#
# This script demonstrates a complete pipeline for extracting text data from PDF files, creating embeddings, storing embeddings in a distributed storage system, and using these embeddings to build a simple context-aware search system.
