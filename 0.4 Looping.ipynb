# %% [markdown]
# ## Looping

# %% [markdown]
# Having learnt about collection of objects in the previous chapter, we will learn about traversing through them using the 2 looping techniques in python viz., <font color = 'blue'><tt>for</tt></font>, and <font color = 'blue'><tt>while</tt></font> loop <br><br><br>
#
#
# <font color = 'blue'><font size = 5><tt><b>For</b></tt></font></font> loops are used to iterate through a sequence of values in a collection
#
# The basic syntax for a <code>for</code> reads as follows
# <div><code><font color = 'indigo'>for item in list:
#     do something with item</font></code></div><br>
#
# For ex:
# <div><code><font color = 'indigo'>x = [1,2,3,4,5,6]
# for i in x:
#     print(i)</font></code></div><br>
#
# <div><font color = 'indigo'><b>Output</b><br>
# 1<br>
# 2<br>
# 3<br>
# 4<br>
# 5<br>
# 6<br></font></div><br>
#
#
# <font color = 'DarkCyan'>Exercise<br> 1. Print only alternate elements from the above list using <font color = 'blue'><tt>for</tt></font> loop</font><br><br>
#
#
# You can also generate a pseudo dictionary or a key/value pair using <font color = 'blue'><tt>for</tt></font> loop and <font color = 'blue'><tt>enumerate</tt></font> funtion
#
#
# For example in the previous chapter I had asked to work on printing the values of elements along with their indices which was joined from another list, alternatively it can be done as below<br><br>
#
#
# <div><code><font color = 'indigo'>x = ['Java', 'Python', 'Golang', 'Rust', 'Julia', React']
# for i,j in enumerate(x):
#     print(i, j)</font></code></div><br>
#
#
#
# <br><br>
# <font color = 'blue'><font size = 5><tt><b>While</b></tt></font></font> loops are used to repeatedly execute a code sequnce.
#
# Basic syntax is as follows
#
# <div><code><font color = 'indigo'>while condition<i>(=True)</i>:
#     do something</font></code></div><br>
#
# Above, condition referes to an expression evalution, the <font color = 'blue'><tt>while</tt></font> loop will execute as long as the condition is satisfied and will exit once the condition is <font color = 'blue'><code>False</code></font>
#
#
# For ex:&nbsp
# <div><code><font color = 'indigo'>i = 1
# while i < 7:
#     print(i)
#     i += 1</font></code></div><br>
#
#
# <div><font color = 'indigo'><b>Output</b><br>
# 1<br>
# 2<br>
# 3<br>
# 4<br>
# 5<br>
# 6<br></font></div><br>
#
#
# To recap a <font color = 'blue'><tt>for</tt></font> loop is used to iterate over a sequence of elements, while a <font color = 'blue'><tt>while</tt></font> loop is used to execute a block of code repeatedly while a certain condition is <code>True</code>.<br><br><br>

# %% [markdown]
# <font color = 'blue'><font size = 5><tt><b>Range()</b></tt></font></font>
#
# Looping can also be used without data struct objects, for ex lets say you want to print the first 20 numbers <font color = 'maroon'>(including 0 - since in python the index starts from 0, not 1)</font><br><br>
#
#
# <div><code><font color = 'indigo'>for i in range(20):
#     print(i)</font></code></div><br>
#
#
# The <font color = 'blue'><tt>Range()</tt></font>  function takes 3 arguments viz., start, stop and step.
#
# <br>Usage:
#
# <div><code><font color = 'indigo'>for i in range(0,12,3)
#     print(i)</font></code></div><br>
#
#
# <div><font color = 'indigo'><b>Output</b><br>
# 0<br>
# 3<br>
# 6<br>
# 9<br>
# 12<br></font></div><br>
#
#
# <font color = 'DarkCyan'>Exercise<br> 2. Write the  <font color = 'blue'><tt>while</tt></font> loop equivalent of the above.</font><br><br>
